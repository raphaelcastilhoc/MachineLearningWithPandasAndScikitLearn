# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("./dataset/adult.data", 
                 names=["age", "workclass", "fnlwgt", "education", "education-num", 
                        "marital-status", "occupation", "relationship", "race",
                        "sex", "capital-gain", "capital-loss", "hours-per-week",
                        "native-country", "income"],
                skipinitialspace=True)

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df.isnull().values.any()
# Out:
# False

# %%
def plot_corr(df, size=25):
    corr = df.apply(lambda x: x.factorize()[0]).corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns)
    plt.yticks(range(len(corr.columns)), corr.columns)

# %%
plot_corr(df)

# %%
df.apply(lambda x: x.factorize()[0]).corr()
# Out:
#                      age  workclass    fnlwgt  education  education-num  \
# age             1.000000   0.071103  0.076682   0.044320       0.044320
# workclass       0.071103   1.000000  0.012767   0.011666       0.011666
# fnlwgt          0.076682   0.012767  1.000000   0.034911       0.034911
# education       0.044320   0.011666  0.034911   1.000000       1.000000
# education-num   0.044320   0.011666  0.034911   1.000000       1.000000
# marital-status  0.097691   0.035949  0.037005   0.008507       0.008507
# occupation      0.061436   0.217072  0.015411   0.074961       0.074961
# relationship   -0.020508   0.015524  0.037741   0.044319       0.044319
# race           -0.013882   0.009359  0.036233   0.029638       0.029638
# sex             0.013328   0.019347  0.090497   0.000550       0.000550
# capital-gain    0.056664   0.025639  0.019787   0.005438       0.005438
# capital-loss    0.017703   0.010242  0.011433   0.005792       0.005792
# hours-per-week  0.080641   0.030301  0.026265   0.046631       0.046631
# native-country -0.010688  -0.010246 -0.010298   0.067619       0.067619
# income         -0.044498   0.047203 -0.058700  -0.046218      -0.046218
#
#                 marital-status  occupation  relationship      race       sex  \
# age                   0.097691    0.061436     -0.020508 -0.013882  0.013328
# workclass             0.035949    0.217072      0.015524  0.009359  0.019347
# fnlwgt                0.037005    0.015411      0.037741  0.036233  0.090497
# education             0.008507    0.074961      0.044319  0.029638  0.000550
# education-num         0.008507    0.074961      0.044319  0.029638  0.000550
# marital-status        1.000000    0.006524      0.029083  0.012722  0.181870
# occupation            0.006524    1.000000     -0.016150  0.016586 -0.147779
# relationship          0.029083   -0.016150      1.000000  0.096808  0.273414
# race                  0.012722    0.016586      0.096808  1.000000  0.067840
# sex                   0.181870   -0.147779      0.273414  0.067840  1.000000
# capital-gain          0.050772   -0.005483     -0.012549 -0.010851 -0.011339
# capital-loss          0.022601   -0.009684     -0.015410 -0.007996 -0.001277
# hours-per-week        0.028753    0.039536      0.025558 -0.020509  0.055507
# native-country        0.001912    0.019578      0.042444  0.241650  0.005977
# income                0.002644   -0.104691     -0.171294 -0.067713 -0.215980
#
#                 capital-gain  capital-loss  hours-per-week  native-country  \
# age                 0.056664      0.017703        0.080641       -0.010688
# workclass           0.025639      0.010242        0.030301       -0.010246
# fnlwgt              0.019787      0.011433        0.026265       -0.010298
# education           0.005438      0.005792        0.046631        0.067619
# education-num       0.005438      0.005792        0.046631        0.067619
# marital-status      0.050772      0.022601        0.028753        0.001912
# occupation         -0.005483     -0.009684        0.039536        0.019578
# relationship       -0.012549     -0.015410        0.025558        0.042444
# race               -0.010851     -0.007996       -0.020509        0.241650
# sex                -0.011339     -0.001277        0.055507        0.005977
# capital-gain        1.000000     -0.035146        0.010059        0.002388
# capital-loss       -0.035146      1.000000        0.010305        0.002527
# hours-per-week      0.010059      0.010305        1.000000       -0.007930
# native-country      0.002388      0.002527       -0.007930        1.000000
# income              0.091250      0.038593       -0.026776       -0.028478
#
#                   income
# age            -0.044498
# workclass       0.047203
# fnlwgt         -0.058700
# education      -0.046218
# education-num  -0.046218
# marital-status  0.002644
# occupation     -0.104691
# relationship   -0.171294
# race           -0.067713
# sex            -0.215980
# capital-gain    0.091250
# capital-loss    0.038593
# hours-per-week -0.026776
# native-country -0.028478
# income          1.000000

# %%
# factorize creates a numeric representation for non numeric types
pd.factorize(['b', 'b', 'a', 'c', 'b'])
# Out:
# (array([0, 0, 1, 2, 0], dtype=int64), array(['b', 'a', 'c'], dtype=object))

# %%
del df['education']

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education-num      marital-status  \
# 0   39         State-gov   77516             13       Never-married
# 1   50  Self-emp-not-inc   83311             13  Married-civ-spouse
# 2   38           Private  215646              9            Divorced
# 3   53           Private  234721              7  Married-civ-spouse
# 4   28           Private  338409             13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week native-country income
# 0             0              40  United-States  <=50K
# 1             0              13  United-States  <=50K
# 2             0              40  United-States  <=50K
# 3             0              40  United-States  <=50K
# 4             0              40           Cuba  <=50K

# %%
plot_corr(df)

# %%
more_than_50k_map = {">50K": 1, "<=50K": 0}

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education-num      marital-status  \
# 0   39         State-gov   77516             13       Never-married
# 1   50  Self-emp-not-inc   83311             13  Married-civ-spouse
# 2   38           Private  215646              9            Divorced
# 3   53           Private  234721              7  Married-civ-spouse
# 4   28           Private  338409             13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week native-country income
# 0             0              40  United-States  <=50K
# 1             0              13  United-States  <=50K
# 2             0              40  United-States  <=50K
# 3             0              40  United-States  <=50K
# 4             0              40           Cuba  <=50K

# %%
df['income'] = df['income'].map(more_than_50k_map)

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt  education-num         marital-status  \
# 0   39         State-gov   77516             13          Never-married
# 1   50  Self-emp-not-inc   83311             13     Married-civ-spouse
# 2   38           Private  215646              9               Divorced
# 3   53           Private  234721              7     Married-civ-spouse
# 4   28           Private  338409             13     Married-civ-spouse
# 5   37           Private  284582             14     Married-civ-spouse
# 6   49           Private  160187              5  Married-spouse-absent
# 7   52  Self-emp-not-inc  209642              9     Married-civ-spouse
# 8   31           Private   45781             14          Never-married
# 9   42           Private  159449             13     Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
# 5    Exec-managerial           Wife  White  Female             0
# 6      Other-service  Not-in-family  Black  Female             0
# 7    Exec-managerial        Husband  White    Male             0
# 8     Prof-specialty  Not-in-family  White  Female         14084
# 9    Exec-managerial        Husband  White    Male          5178
#
#    capital-loss  hours-per-week native-country  income
# 0             0              40  United-States       0
# 1             0              13  United-States       0
# 2             0              40  United-States       0
# 3             0              40  United-States       0
# 4             0              40           Cuba       0
# 5             0              40  United-States       0
# 6             0              16        Jamaica       0
# 7             0              45  United-States       1
# 8             0              50  United-States       1
# 9             0              40  United-States       1

# %%
true_len = len(df.loc[df['income'] == True])

# %%
false_len = len(df.loc[df['income'] == False])

# %%
print("Number of true: {0}. Percentage:{1:2.2f}%".format(true_len, (true_len / (true_len + false_len)) * 100))
# Out:
# Number of true: 7841. Percentage:24.08%

# %%
print("Number of false: {0}. Percentage:{1:2.2f}%".format(false_len, (false_len / (false_len + true_len)) * 100))
# Out:
# Number of false: 24720. Percentage:75.92%

# %%
from sklearn.model_selection import train_test_split
feature_columns = ["workclass"]
class_column = ["income"]

# %%
x = df[feature_columns].values
y = df[class_column].values

split_test_percentage = 0.30

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = split_test_percentage, random_state=42)

# %%
print("{0:0.2f}% in traning set".format(len(x_train)/len(df.index) * 100))
print("{0:0.2f}% in test set".format(len(x_test)/len(df.index) * 100))
# Out:
# 70.00% in traning set
# 30.00% in test set

# %%
print("Original True  : {0} ({1:0.2f}%)".format(len(df.loc[df['income'] == 1]), (len(df.loc[df['income'] == 1])/len(df.index)) * 100.0))
print("Original False : {0} ({1:0.2f}%)".format(len(df.loc[df['income'] == 0]), (len(df.loc[df['income'] == 0])/len(df.index)) * 100.0))
print("")

# Check if "make more than 50k true and false" were splited correctly in 70% and 30% on Training data
print("Training True  : {0} ({1:0.2f}%)".format(len(y_train[y_train[:] == 1]), (len(y_train[y_train[:] == 1])/len(y_train) * 100.0)))
print("Training False : {0} ({1:0.2f}%)".format(len(y_train[y_train[:] == 0]), (len(y_train[y_train[:] == 0])/len(y_train) * 100.0)))
print("")

# Check if "make more than 50k true and false" were splited correctly in 70% and 30% on Test data
print("Test True      : {0} ({1:0.2f}%)".format(len(y_test[y_test[:] == 1]), (len(y_test[y_test[:] == 1])/len(y_test) * 100.0)))
print("Test False     : {0} ({1:0.2f}%)".format(len(y_test[y_test[:] == 0]), (len(y_test[y_test[:] == 0])/len(y_test) * 100.0)))
# Out:
# Original True  : 7841 (24.08%)
# Original False : 24720 (75.92%)
#
# Training True  : 5527 (24.25%)
# Training False : 17265 (75.75%)
#
# Test True      : 2314 (23.69%)
# Test False     : 7455 (76.31%)

# %%
print("# rows in dataframe {0}".format(len(df)))
print("# rows missing age: {0}".format(len(df.loc[df['age'] == 0])))
print("# rows missing workclass: {0}".format(len(df.loc[df['workclass'] == ""])))
print("# rows missing fnlwgt: {0}".format(len(df.loc[df['fnlwgt'] == 0])))
print("# rows missing education-num: {0}".format(len(df.loc[df['education-num'] == 0])))
print("# rows missing marital-status: {0}".format(len(df.loc[df['marital-status'] == ""])))
print("# rows missing occupation: {0}".format(len(df.loc[df['occupation'] == ""])))
print("# rows missing relationship: {0}".format(len(df.loc[df['relationship'] == ""])))
print("# rows missing race: {0}".format(len(df.loc[df['race'] == ""])))
print("# rows missing sex: {0}".format(len(df.loc[df['sex'] == ""])))
print("# rows missing capital-gain: {0}".format(len(df.loc[df['capital-gain'] == 0])))
print("# rows missing capital-loss: {0}".format(len(df.loc[df['capital-loss'] == 0])))
print("# rows missing hours-per-week: {0}".format(len(df.loc[df['hours-per-week'] == 0])))
print("# rows missing native-country: {0}".format(len(df.loc[df['native-country'] == ""])))
# Out:
# # rows in dataframe 32561
# # rows missing age: 0
# # rows missing workclass: 0
# # rows missing fnlwgt: 0
# # rows missing education-num: 0
# # rows missing marital-status: 0
# # rows missing occupation: 0
# # rows missing relationship: 0
# # rows missing race: 0
# # rows missing sex: 0
# # rows missing capital-gain: 29849
# # rows missing capital-loss: 31042
# # rows missing hours-per-week: 0
# # rows missing native-country: 0

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

model = Pipeline([('vect', CountVectorizer()),
                  ('tfidf', TfidfTransformer()),
                  ('clf', MultinomialNB())
                 ])
model
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...inear_tf=False, use_idf=True)), ('clf', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
from sklearn.model_selection import cross_validate

scores = cross_validate(model, x_train.ravel(), y_train.ravel(), cv=10, scoring=['accuracy','f1_macro','f1_weighted'], return_train_score=True)
scores
# Out:
# C:\Users\Raphael\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Raphael\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Raphael\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Raphael\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Raphael\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Raphael\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Raphael\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Raphael\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Raphael\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Raphael\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# {'fit_time': array([0.05989933, 0.051301  , 0.05093169, 0.05190921, 0.05206728,
#         0.0519495 , 0.05790091, 0.05172992, 0.05385566, 0.05578709]),
#  'score_time': array([0.01793981, 0.0229826 , 0.02195883, 0.02224422, 0.02061415,
#         0.02198195, 0.02094483, 0.02129626, 0.02298236, 0.02393603]),
#  'test_accuracy': array([0.75745614, 0.75745614, 0.75745614, 0.75745614, 0.75745614,
#         0.75734971, 0.75734971, 0.75768218, 0.75768218, 0.75768218]),
#  'train_accuracy': array([0.7575078 , 0.7575078 , 0.7575078 , 0.7575078 , 0.7575078 ,
#         0.75751962, 0.75751962, 0.75748269, 0.75748269, 0.75748269]),
#  'test_f1_macro': array([0.43099576, 0.43099576, 0.43099576, 0.43099576, 0.43099576,
#         0.4309613 , 0.4309613 , 0.43106893, 0.43106893, 0.43106893]),
#  'train_f1_macro': array([0.43101248, 0.43101248, 0.43101248, 0.43101248, 0.43101248,
#         0.43101631, 0.43101631, 0.43100435, 0.43100435, 0.43100435]),
#  'test_f1_weighted': array([0.65292077, 0.65292077, 0.65292077, 0.65292077, 0.65292077,
#         0.65277683, 0.65277683, 0.65322649, 0.65322649, 0.65322649]),
#  'train_f1_weighted': array([0.65299064, 0.65299064, 0.65299064, 0.65299064, 0.65299064,
#         0.65300662, 0.65300662, 0.65295668, 0.65295668, 0.65295668])}

# %%
scores_df = pd.DataFrame(scores)
scores_df.mean()*100
# Out:
# fit_time             5.228348
# score_time           2.102730
# test_accuracy       75.750267
# test_f1_macro       43.101082
# test_f1_weighted    65.298370
# dtype: float64

# %%
scores_df.describe()
# Out:
#         fit_time  score_time  test_accuracy  test_f1_macro  test_f1_weighted
# count  10.000000   10.000000      10.000000      10.000000         10.000000
# mean    0.052283    0.021027       0.757503       0.431011          0.652984
# std     0.003746    0.005030       0.000131       0.000042          0.000177
# min     0.049865    0.017920       0.757350       0.430961          0.652777
# 25%     0.049899    0.018891       0.757456       0.430996          0.652921
# 50%     0.050887    0.018952       0.757456       0.430996          0.652921
# 75%     0.052633    0.020678       0.757626       0.431051          0.653150
# max     0.061878    0.034940       0.757682       0.431069          0.653226

# %%
model.fit(x_train.ravel(),y_train.ravel())
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...inear_tf=False, use_idf=True)), ('clf', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
model.predict(['Self-emp-not-inc'])
# Out:
# array([0], dtype=int64)

# %%
df[df['workclass'] == 'Private']
# Out:
#        age workclass  fnlwgt  education-num         marital-status  \
# 2       38   Private  215646              9               Divorced
# 3       53   Private  234721              7     Married-civ-spouse
# 4       28   Private  338409             13     Married-civ-spouse
# 5       37   Private  284582             14     Married-civ-spouse
# 6       49   Private  160187              5  Married-spouse-absent
# 8       31   Private   45781             14          Never-married
# 9       42   Private  159449             13     Married-civ-spouse
# 10      37   Private  280464             10     Married-civ-spouse
# 12      23   Private  122272             13          Never-married
# 13      32   Private  205019             12          Never-married
# 14      40   Private  121772             11     Married-civ-spouse
# 15      34   Private  245487              4     Married-civ-spouse
# 17      32   Private  186824              9          Never-married
# 18      38   Private   28887              7     Married-civ-spouse
# 20      40   Private  193524             16     Married-civ-spouse
# 21      54   Private  302146              9              Separated
# 23      43   Private  117037              7     Married-civ-spouse
# 24      59   Private  109015              9               Divorced
# 26      19   Private  168294              9          Never-married
# 28      39   Private  367260              9               Divorced
# 29      49   Private  193366              9     Married-civ-spouse
# 31      20   Private  266015             10          Never-married
# 32      45   Private  386940             13               Divorced
# 35      48   Private  242406              7          Never-married
# 36      21   Private  197200             10          Never-married
# 37      19   Private  544091              9      Married-AF-spouse
# 38      31   Private   84154             10     Married-civ-spouse
# 40      31   Private  507875              5     Married-civ-spouse
# 42      24   Private  172987             13     Married-civ-spouse
# 43      49   Private   94638              9              Separated
# ...    ...       ...     ...            ...                    ...
# 32517   36   Private  131459              4     Married-civ-spouse
# 32519   46   Private  364548             10     Married-civ-spouse
# 32520   27   Private  177398              9          Never-married
# 32521   33   Private  273243              9     Married-civ-spouse
# 32522   58   Private  147707              7     Married-civ-spouse
# 32523   30   Private   77266              9               Divorced
# 32524   26   Private  191648             12          Never-married
# 32526   32   Private  211349              6     Married-civ-spouse
# 32527   22   Private  203715             10          Never-married
# 32528   31   Private  292592              9     Married-civ-spouse
# 32529   29   Private  125976              9              Separated
# 32532   34   Private  204461             16     Married-civ-spouse
# 32533   54   Private  337992             13     Married-civ-spouse
# 32534   37   Private  179137             10               Divorced
# 32535   22   Private  325033              8          Never-married
# 32536   34   Private  160216             13          Never-married
# 32537   30   Private  345898              9          Never-married
# 32538   38   Private  139180             13               Divorced
# 32544   31   Private  199655             14               Divorced
# 32546   37   Private  198216             12               Divorced
# 32547   43   Private  260761              9     Married-civ-spouse
# 32551   32   Private   34066              6     Married-civ-spouse
# 32552   43   Private   84661             11     Married-civ-spouse
# 32553   32   Private  116138             14          Never-married
# 32554   53   Private  321865             14     Married-civ-spouse
# 32555   22   Private  310152             10          Never-married
